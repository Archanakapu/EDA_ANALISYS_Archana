# %%
import pandas as pd

# %%
movies=pd.read_csv(r'F:\Pyton tasks\Movie-Rating - Movie-Rating_f27.csv')

# %%
movies
# Out:
#                      Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer     Comedy                         87
# 1             10,000 B.C.  Adventure                          9
# 2               12 Rounds     Action                         30
# 3               127 Hours  Adventure                         93
# 4                17 Again     Comedy                         55
# ..                    ...        ...                        ...
# 554         Your Highness     Comedy                         26
# 555       Youth in Revolt     Comedy                         68
# 556                Zodiac   Thriller                         89
# 557            Zombieland     Action                         90
# 558             Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# ...

# %%
movies.head(5)
# Out:
#                    Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer     Comedy                         87
# 1           10,000 B.C.  Adventure                          9
# 2             12 Rounds     Action                         30
# 3             127 Hours  Adventure                         93
# 4              17 Again     Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movies.tail(5)
# Out:
#                 Film     Genre  Rotten Tomatoes Ratings %  Audience Ratings %  \
# 554    Your Highness    Comedy                         26                  36
# 555  Youth in Revolt    Comedy                         68                  52
# 556           Zodiac  Thriller                         89                  73
# 557       Zombieland    Action                         90                  87
# 558        Zookeeper    Comedy                         14                  42
#
#      Budget (million $)  Year of release
# 554                  50             2011
# 555                  18             2009
# 556                  65             2007
# 557                  24             2009
# 558                  80             2011

# %%
len(movies)
# Out:
# 559

# %%
type(movies)
# Out:
# pandas.core.frame.DataFrame

# %%
import numpy

# %%
print(numpy.__version__)
# Out:
# 1.26.4

# %%
import pandas

# %%
print(pandas.__version__)
# Out:
# 2.2.2

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Film                       559 non-null    object
#  1   Genre                      559 non-null    object
#  2   Rotten Tomatoes Ratings %  559 non-null    int64
#  3   Audience Ratings %         559 non-null    int64
#  4   Budget (million $)         559 non-null    int64
#  5   Year of release            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.shape
# Out:
# (559, 6)

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.columns=['Film','Genre','CriticRating','AudienceRating','BudgetMillions','Year']

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'CriticRating', 'AudienceRating', 'BudgetMillions',
#        'Year'],
#       dtype='object')

# %%
movies.head(1)
# Out:
#                    Film   Genre  CriticRating  AudienceRating  BudgetMillions  \
# 0  (500) Days of Summer  Comedy            87              81               8
#
#    Year
# 0  2009

# %%
movies.describe
# Out:
# <bound method NDFrame.describe of                      Film      Genre  CriticRating  AudienceRating  \
# 0    (500) Days of Summer     Comedy            87              81
# 1             10,000 B.C.  Adventure             9              44
# 2               12 Rounds     Action            30              52
# 3               127 Hours  Adventure            93              84
# 4                17 Again     Comedy            55              70
# ..                    ...        ...           ...             ...
# 554         Your Highness     Comedy            26              36
# 555       Youth in Revolt     Comedy            68              52
# 556                Zodiac   Thriller            89              73
# 557            Zombieland     Action            90              87
# 558             Zookeeper     Comedy            14              42
#
#      BudgetMillions  Year
# 0                 8  2009
# 1               105  2008
# 2                20  2009
# ...

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillions         Year
# count    559.000000      559.000000      559.000000   559.000000
# mean      47.309481       58.744186       50.236136  2009.152057
# std       26.413091       16.826887       48.731817     1.362632
# min        0.000000        0.000000        0.000000  2007.000000
# 25%       25.000000       47.000000       20.000000  2008.000000
# 50%       46.000000       58.000000       35.000000  2009.000000
# 75%       70.000000       72.000000       65.000000  2010.000000
# max       97.000000       96.000000      300.000000  2011.000000

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    object
#  1   Genre           559 non-null    object
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.Film=movies.Film.astype('category')

# %%
movies.Genre=movies.Genre.astype('category')

# %%
movies.Year=movies.Year.astype('category')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    category
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 36.5 KB

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillions
# count    559.000000      559.000000      559.000000
# mean      47.309481       58.744186       50.236136
# std       26.413091       16.826887       48.731817
# min        0.000000        0.000000        0.000000
# 25%       25.000000       47.000000       20.000000
# 50%       46.000000       58.000000       35.000000
# 75%       70.000000       72.000000       65.000000
# max       97.000000       96.000000      300.000000

# %%
from matplotlib import pyplot as plt  # Visualization
import seaborn as sns  # Advanced visualization
# %matplotlib inline  # All the plots should appear within the notebook
import warnings  # Corrected spelling
warnings.filterwarnings('ignore')  # Ignore warnings
# Out:
# UsageError: unrecognized arguments: # All the plots should appear within the notebook

# %%
j = sns.jointplot(data=movies, x='CriticRating', y='AudienceRating')
plt.show()

# %%
j = sns.jointplot(data=movies, x='CriticRating', y='AudienceRating',kind='scatter')
plt.show()

# %%
j = sns.jointplot(data=movies, x='CriticRating', y='AudienceRating',kind='kde')
plt.show()

# %%
j = sns.jointplot(data=movies, x='CriticRating', y='AudienceRating',kind='hist')
plt.show()

# %%
j = sns.jointplot(data=movies, x='CriticRating', y='AudienceRating',kind='hex')
plt.show()

# %%
j = sns.jointplot(data=movies, x='CriticRating', y='AudienceRating',kind='reg')
plt.show()

# %%
j = sns.jointplot(data=movies, x='CriticRating', y='AudienceRating',kind='resid')
plt.show()

# %%
m1=sns.distplot(movies.AudienceRating)
plt.show()
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_17076\200986629.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   m1=sns.distplot(movies.AudienceRating)

# %%
m2=sns.distplot(movies.CriticRating)
plt.show()
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_17076\250090766.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   m2=sns.distplot(movies.CriticRating)

# %%
sns.set_style=('darkgrid')
m3=sns.distplot(movies.AudienceRating,bins=10)
plt.show()
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_17076\3433080017.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   m3=sns.distplot(movies.AudienceRating,bins=10)

# %%
sns.set_style=('white')
m3=sns.distplot(movies.AudienceRating,bins=15)
plt.show()
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_17076\1278830526.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   m3=sns.distplot(movies.AudienceRating,bins=15)

# %%
sns.set_style=('white')
n1=plt.hist(movies.AudienceRating,bins=20)
plt.show()

# %%
sns.set_style=('white')
n1=plt.hist(movies.CriticRating,bins=20)
plt.show()

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'CriticRating', 'AudienceRating', 'BudgetMillions',
#        'Year'],
#       dtype='object')

# %%
bm=plt.hist(movies.BudgetMillions,bins=20)
plt.show()

# %%
vis=sns.lmplot(data=movies,x='AudienceRating',y='CriticRating')
plt.show()

# %%
a2=sns.boxplot(data=movies,x='Genre',y='CriticRating')
plt.show()

# %%
a2=sns.violinplot(data=movies,x='Genre',y='CriticRating')
plt.show()

# %%
vis1=sns.lmplot(data=movies,x='CriticRating',y='AudienceRating',fit_reg='False',hue='Genre')
plt.show()

# %%
vis2=sns.lmplot(data=movies,x='CriticRating',y='AudienceRating',fit_reg='True',hue='Genre')
plt.show()

# %%
ax=plt.subplots(3,3,figsize=(10,8))

# %%
ax=plt.subplots(1,2,figsize=(10,8))
